# %%
import pandas as pd

df = pd.read_csv('data/atp_matches_2025.csv')

df['tourney_level'] = df['tourney_level'].replace(['250','500'], 'A')

df.to_csv('atp_matches_2025.csv', index=False, header=True)
